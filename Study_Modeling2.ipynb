# %% [markdown]
# # Study Modeling 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. HDS 데이터 분석

# %% [markdown]
# ### 1.1 Load 데이터

# %%
hds_df = pd.read_csv('D:/sglee/DseyKorea/data/HDS.csv', header=0) # header=0 means the first row of data. If no header, header=None.

# %%
hds_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Columns: 2933 entries, Y-1 to CD.AVG
# dtypes: float64(2717), int64(216)
# memory usage: 1.5 MB

# %%
# hds_df = hds_df.loc[:, hds_df.dtypes != np.object]

# %%
train_df = hds_df[:50:1]

# %%
test_df = hds_df[50::1]

# %% [markdown]
# ### 1.2 OLS Model

# %%
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
train_columns = [c for c in train_df.columns if c not in ['Y-1']]

model = sm.OLS(train_df['Y-1'].values, train_df[train_columns])
result = model.fit()
print(result.summary())
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\statsmodels\regression\linear_model.py:1648: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\statsmodels\regression\linear_model.py:1649: RuntimeWarning: invalid value encountered in double_scalars
#   * (1 - self.rsquared))
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\statsmodels\regression\linear_model.py:1665: RuntimeWarning: divide by zero encountered in double_scalars
#   return self.ssr/self.df_resid
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\statsmodels\regression\linear_model.py:1578: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid
# ...

# %% [markdown]
# ## 1. V사 ELA 데이터 분석

# %% [markdown]
# ### 1.1 Load 데이터

# %%
ela_df = pd.read_csv('D:/sglee/DseyKorea/data/V_data/11300-113A0-joined.csv', header=0) # header=0 means the first row of data. If no header, header=None.

# %%
ela_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Columns: 141 entries, Slot to S07-0-0_EXIT_CV_ION_FLOW
# dtypes: float64(100), int64(35), object(6)
# memory usage: 35.3+ KB
