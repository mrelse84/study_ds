# %% [markdown]
# # Study Visualize

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns #Visulization

# %% [markdown]
# ## Iris Data

# %%
iris = pd.read_csv('D:\sglee\DseyKorea\data\open_data\iris.csv', header=0)

# %%
iris[['sepal_length','species']].groupby('species').count()
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ## Scatter Plot

# %%
fig, ax = plt.subplots(figsize=(8,5))
colors = {'setosa': 'r', 'versicolor': 'g', 'virginica': 'b'}
for i in range(len(iris['sepal_length'])):
    ax.scatter(iris['petal_length'][i], iris['petal_width'][i], color=colors[iris['species'][i]])
ax.set_title('Iris Dataset')
ax.set_xlabel('petal_length')
ax.set_ylabel('petal_width')
# Out:
# Text(0, 0.5, 'petal_width')

# %% [markdown]
# ## Line Chart

# %%
columns = iris.columns.drop(['species'])
x_data = range(0, iris.shape[0])
fig, ax = plt.subplots(figsize=(8,5))
for column in columns:
    ax.plot(x_data, iris[column], label=column)
ax.set_title('Iris Dataset')
ax.legend()

# %% [markdown]
# ## Seaborn's Histogram

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.distplot(iris['petal_length'])

# %% [markdown]
# ## Seaborn's Heatmap

# %%
# correlation이 높은 상위 4개의 heatmap
# continuous variables --> pearson
# continuous + sequential variables --> spearman
# abs는 반비례관계도 고려하기 위함
import scipy as sp

cor_abs = abs(iris.corr(method='spearman')) 
cor_cols = cor_abs.nlargest(n=4, columns='petal_length').index # petal_length correlation이 높은 column 4개 뽑기(내림차순)
# spearman coefficient matrix
cor = np.array(sp.stats.spearmanr(iris[cor_cols].values))[0] # 4 x 4
print(cor_cols.values)
plt.figure(figsize=(10,10))
sns.set(font_scale=1.25)
sns.heatmap(cor, fmt='.2f', annot=True, square=True , annot_kws={'size' : 8} ,xticklabels=cor_cols.values, yticklabels=cor_cols.values)
# Out:
# ['petal_length' 'petal_width' 'sepal_length' 'sepal_width']

# %% [markdown]
# ## Wine Review Data

# %%
wine_reviews = pd.read_csv('D:\sglee\DseyKorea\data\open_data\winemag-data-130k-v2.csv', index_col=0)
wine_reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
wine_reviews.describe()
# Out:
#               points          price
# count  129971.000000  120975.000000
# mean       88.447138      35.363389
# std         3.039730      41.022218
# min        80.000000       4.000000
# 25%        86.000000      17.000000
# 50%        88.000000      25.000000
# 75%        91.000000      42.000000
# max       100.000000    3300.000000

# %% [markdown]
# ## Histogram

# %%
# create figure and axis
fig, ax = plt.subplots()
# plot histogram
ax.hist(wine_reviews['points'])
# set title and labels
ax.set_title('Wine Review Scores')
ax.set_xlabel('Points')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Bar Chart

# %%
# create a figure and axis 
fig, ax = plt.subplots() 
# count the occurrence of each class 
data = wine_reviews['points'].value_counts() 
# get x and y data 
points = data.index 
frequency = data.values 
# create bar chart 
ax.bar(points, frequency) 
# set title and labels 
ax.set_title('Wine Review Scores') 
ax.set_xlabel('Points') 
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Sine Graph

# %%
fig, ax = plt.subplots(figsize=(8,5)) 
r = 1
ax.plot(np.linspace(-5, 5, 100), np.sin(np.linspace(-5, 5, 100)))

# %% [markdown]
# ## Cycloid Graph

# %%
fig, ax = plt.subplots(figsize=(8,5)) 
r = 1
theta = np.linspace(0, 2*np.pi*r, 100)
ax.plot(r*(theta-np.sin(theta)), r*(1-np.cos(theta)))

# %% [markdown]
# ## 음함수 그리기

# %%
from sympy import *
init_printing()             # 수식을 보기좋게 출력하는 함수를 호출한다

# %%
x, y, z, t = symbols('x y z t')

plot( 2*x-1, (x,-2,3) )

# %%
# 원의 방정식
Ys = solve( Eq( x**2 + y**2, 1 ), y )
Ys
# Out:
# ⎡    ________     ________⎤
# ⎢   ╱      2     ╱      2 ⎥
# ⎣-╲╱  1 - x  , ╲╱  1 - x  ⎦

# %%
plot( Ys[0], Ys[1], xlim=(-3,3), ylim=(-2,2) )

# %%
plot_implicit( Eq( x**2 + y**2, 1 ), (x,-3,3), (y,-2,2) )

# %%
plot_implicit( Eq( 3*x**2 + 2*x*y + 3*y**2 - 2, 0 ), (x,-3,3), (y,-2,2) )

# %%
plot_implicit( Eq( -x**2 - 6*x*y - y**2 + 8, 0 ), (x,-3,3), (y,-2,2) )

# %%
plot_implicit( Eq( x**2/2 - y**2/4 - 1, 0 ), (x,-3,3), (y,-2,2) )

# %%
plot_implicit( Or( Eq( x**2+y**2,4 ), Eq( 2*x-y+1,0 ) ), (x,-4,5), (y,-3,3) )

# %%
x = np.arange(-2, 2, 0.1)
y = np.arange(-2, 2, 0.1)

# %%
X, Y = np.meshgrid(x, y)
Z = 3*X*X + 2*X*Y + 3*Y*Y - 2

# %%
import matplotlib

# %%
matplotlib.rcParams['contour.negative_linestyle'] = 'solid'

# %%
plt.figure()

# %%
CS = plt.contour(X, Y, Z, 1, colors='k')
